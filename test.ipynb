# %%
from main_simple_lib import *
# Out:
# /encoder/layer/0/crossattention/self/query is tied
# /encoder/layer/0/crossattention/self/key is tied
# /encoder/layer/0/crossattention/self/value is tied
# /encoder/layer/0/crossattention/output/dense is tied
# /encoder/layer/0/crossattention/output/LayerNorm is tied
# /encoder/layer/0/intermediate/dense is tied
# /encoder/layer/0/output/dense is tied
# /encoder/layer/0/output/LayerNorm is tied
# /encoder/layer/1/crossattention/self/query is tied
# /encoder/layer/1/crossattention/self/key is tied
# /encoder/layer/1/crossattention/self/value is tied
# /encoder/layer/1/crossattention/output/dense is tied
# /encoder/layer/1/crossattention/output/LayerNorm is tied
# /encoder/layer/1/intermediate/dense is tied
# /encoder/layer/1/output/dense is tied
# /encoder/layer/1/output/LayerNorm is tied
# --------------
# /public26_data/lsx/vipergpt/pretrained_models/ram/ram_swin_large_14m.pth
# --------------
# ...

# %%
path = "/public26_data/lsx/test/MME_S/ocr/0001.jpg"
im = load_image(path)
query = 'is the word "愚园路" in the picture?'
show_single_image(im)
code = get_code(query)
# Out:
# <PIL.Image.Image image mode=RGB size=400x212>
#   0 def execute_command(image):
#   1     image_patch = ImagePatch(image)
#   2     word = image_patch.ocr()
#   3     target = '愚园路'
#   4     joined_string = ''.join(word)
#   5     if target in joined_string:
#   6         return "yes"
#   7     else:
#   8         return "no"

# %%
execute_code(code, im, show_intermediate_steps=True)
# Out:
# <style>.output_wrapper, .output {height:auto !important; max-height:1000000px;}</style>
# Output()
# ───────────────────────────────────────────────────── Line 1 ──────────────────────────────────────────────────────
# image_patch =
# ───────────────────────────────────────────────────── Line 2 ──────────────────────────────────────────────────────
# word[0] = 西
# word[1] = 愚园路
# word[2] = 东
# word[3] = 315
# word[4] = 309
# word[5] = I
# word[6] = Yuyuan Rd。
# word[7] = E
# ───────────────────────────────────────────────────── Line 3 ──────────────────────────────────────────────────────
# target = 愚园路
# ───────────────────────────────────────────────────── Line 4 ──────────────────────────────────────────────────────
# joined_string = 西愚园路东315309IYuyuan Rd。E
# ───────────────────────────────────────────────────── Line 5 ──────────────────────────────────────────────────────
# target in joined_string = True
# ...

# %%
path = "/public26_data/lsx/test/MME_Benchmark_release_version/position/000000014038.jpg"
im = load_image(path)
query = 'the keyword of the picture'
show_single_image(im)
code = get_code(query)
# Out:
# <PIL.Image.Image image mode=RGB size=400x267>
#   0 def execute_command(image) -> list:
#   1     image_patch = ImagePatch(image)
#   2     keyword = image_patch.get_keyword()
#   3     return keyword

# %%
execute_code(code, im, show_intermediate_steps=True)
# Out:
# <style>.output_wrapper, .output {height:auto !important; max-height:1000000px;}</style>
# Output()
# ───────────────────────────────────────────────────── Line 1 ──────────────────────────────────────────────────────
# image_patch =
# ───────────────────────────────────────────────────── Line 2 ──────────────────────────────────────────────────────
# keyword[0] = apartment
# keyword[1] = balloon
# keyword[2] = ceiling
# keyword[3] = chandelier
# keyword[4] = decorate
# keyword[5] = fill
# keyword[6] = floor
# keyword[7] = furniture
# keyword[8] = homeappliance
# keyword[9] = livingroom
# keyword[10] = room
# keyword[11] = woodfloor
# keyword[12] = yellow
# ───────────────────────────────────────────────────── Line 3 ──────────────────────────────────────────────────────
# keyword[0] = apartment
# keyword[1] = balloon
# keyword[2] = ceiling
# keyword[3] = chandelier
# keyword[4] = decorate
# keyword[5] = fill
# keyword[6] = floor
# keyword[7] = furniture
# keyword[8] = homeappliance
# ...
